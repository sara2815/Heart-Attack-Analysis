# %% [markdown]
# Title(Yet to be Determined)

# %%
library(tidyverse)
# Out:
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.1 ──
#
# ✔ ggplot2 3.3.6     ✔ purrr   0.3.4
# ✔ tibble  3.1.7     ✔ dplyr   1.0.9
# ✔ tidyr   1.2.0     ✔ stringr 1.4.0
# ✔ readr   2.1.2     ✔ forcats 0.5.1
#
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()

# %%
cleveland_data_processed <- read_csv("https://archive.ics.uci.edu/ml/machine-learning-databases/heart-disease/processed.cleveland.data", col_names= FALSE)
# Out:
# Rows: 303 Columns: 14
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr  (2): X12, X13
# dbl (12): X1, X2, X3, X4, X5, X6, X7, X8, X9, X10, X11, X14
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.

# %%
colnames_cleveland_data_processed <- rename(cleveland_data_processed,"age" = X1,
"sex" = X2,
"chest_pain_type" = X3,                                          
"resting_bp" = X4,
"cholestrol" = X5,
"fasting_blood_sugar"= X6,
"resting_electrocardiographic" = X7,
"max_heart_rate"= X8,
"exercise_induced_angin_binary"= X9,
"ST_depression_induced_exercise"= X10,
"slope_of_peak_exc"=X11,
"#of_vessels"= X12,
"defect_level"= X13,
"heart_disease_cat" = X14)

colnames_cleveland_data_processed
# Out:
#     age sex chest_pain_type resting_bp cholestrol fasting_blood_sugar
# 1   63  1   1               145        233        1
# 2   67  1   4               160        286        0
# 3   67  1   4               120        229        0
# 4   37  1   3               130        250        0
# 5   41  0   2               130        204        0
# 6   56  1   2               120        236        0
# 7   62  0   4               140        268        0
# 8   57  0   4               120        354        0
# 9   63  1   4               130        254        0
# 10  53  1   4               140        203        1
# 11  57  1   4               140        192        0
# 12  56  0   2               140        294        0
# 13  56  1   3               130        256        1
# 14  44  1   2               120        263        0
# 15  52  1   3               172        199        1
# 16  57  1   3               150        168        0
# 17  48  1   2               110        229        0
# ...

# %%
read_csv("https://raw.githubusercontent.com/RohanBadini/DSCI-Group-43-Project/main/Bollywood%20Dataset.csv")
# Out:
# New names:
# • `Director` -> `Director...10`
# • `Director` -> `Director...20`
# Rows: 981 Columns: 23
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr (15): Movie Name, Release Period, Whether Remake, Whether Franchise, Gen...
# dbl  (8): Number of Screens, Budget(INR), Revenue(INR), ProfitFactor, Year, ...
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#     Movie Name                     Release Period Whether Remake
# 1   Bheja Fry                      Holiday        No
# 2   Aashiqui 2                     Normal         Yes
# 3   Tanu Weds Manu Returns         Normal         No
# 4   Vivah                          Normal         No
# 5   Vicky Donor                    Normal         No
# 6   Malamaal Weekly                Normal         No
# 7   Dabangg                        Holiday        No
# ...
